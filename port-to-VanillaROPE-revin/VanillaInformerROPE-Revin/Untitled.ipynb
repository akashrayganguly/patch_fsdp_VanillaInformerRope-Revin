# %%
import torch
print("GPUs available:", torch.cuda.device_count())
i= 0 
while True:
    print(torch.cuda.get_device_properties(i))
    i = i+1
# Out:
# GPUs available: 2
# _CudaDeviceProperties(name='NVIDIA A40', major=8, minor=6, total_memory=45466MB, multi_processor_count=84, uuid=ffd00ef8-2051-2709-e66f-6da454b34899, L2_cache_size=6MB)
# _CudaDeviceProperties(name='NVIDIA A40', major=8, minor=6, total_memory=45466MB, multi_processor_count=84, uuid=7cd54cea-03a8-1fa1-a7c1-19f025b6604e, L2_cache_size=6MB)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 5
#       3 i= 0
#       4 while True:
# ----> 5     print(torch.cuda.get_device_properties(i))
#       6     i = i+1
#
# File ~/miniconda3/envs/informerworking/lib/python3.10/site-packages/torch/cuda/__init__.py:526, in get_device_properties(device)
#     524 device = _get_device_index(device, optional=True)
#     525 if device < 0 or device >= device_count():
# --> 526     raise AssertionError("Invalid device id")
# ...

# %%
device = _get_device_index(device, optional=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 device = _get_device_index(device, optional=True)
#
# NameError: name '_get_device_index' is not defined

# %%
# If you're already using a CUDA tensor or model
device_index = torch.cuda.current_device()
print(f"Current CUDA Device Index: {device_index}")
print(f"Current CUDA Device Name: {torch.cuda.get_device_name(device_index)}")
# Out:
# Current CUDA Device Index: 0
# Current CUDA Device Name: NVIDIA A40

# %%
import torch

# Check how many CUDA devices are available
num_devices = torch.cuda.device_count()
print(f"Number of available CUDA devices: {num_devices}")

# List all device indices and names
for i in range(num_devices):
    print(f"Device Index: {i}, Device Name: {torch.cuda.get_device_name(i)}")
# Out:
# Number of available CUDA devices: 2
# Device Index: 0, Device Name: NVIDIA A40
# Device Index: 1, Device Name: NVIDIA A40

# %%
torch.cuda.set_device(1)

# %%
print(f"Current CUDA Device Name: {torch.cuda.get_device_name(device_index)}")
# Out:
# Current CUDA Device Name: NVIDIA A40

# %%
device_index = torch.cuda.current_device()
print(f"Current CUDA Device Index: {device_index}")
print(f"Current CUDA Device Name: {torch.cuda.get_device_name(device_index)}")
# Out:
# Current CUDA Device Index: 1
# Current CUDA Device Name: NVIDIA A40
